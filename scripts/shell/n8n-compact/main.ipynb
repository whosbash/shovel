# %%
# !pip install python-statemachine
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: python-statemachine in /home/brunolnetto/.local/lib/python3.10/site-packages (2.4.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import signal
import time
from statemachine import State, StateMachine
from datetime import datetime  # For logging timestamps


class TrafficLightMachine(StateMachine):
    "A traffic light machine"

    green = State(initial=True)
    yellow = State()
    red = State()

    cycle = green.to(yellow) | yellow.to(red) | red.to(green)

    def before_cycle(self, event: str, source: State, target: State):
        print(f"Running {event} from {source.id} to {target.id}")


class Supervisor:
    def __init__(self, sm: StateMachine, sm_event: str):
        self.sm = sm
        self.sm_event = sm_event
        self.running = True

    def signal_handler(self, signum, frame):
        """Handle the periodic signal to trigger state transitions."""
        if self.running:
            # Log the event with a timestamp
            print(f"{datetime.now().isoformat()} - Signal received: {signum}. Triggering event: {self.sm_event}")
            self.sm.send(self.sm_event)

    def start(self, interval: float):
        """Start the supervisor with a periodic signal."""
        # Convert interval to seconds for signal ITIMER_REAL
        signal.signal(signal.SIGALRM, self.signal_handler)
        signal.setitimer(signal.ITIMER_REAL, interval, interval)

    def stop(self):
        """Stop the periodic signal."""
        self.running = False
        signal.setitimer(signal.ITIMER_REAL, 0)  # Disable the timer


# Initialize the state machine and supervisor
traffic_light = TrafficLightMachine()
supervisor = Supervisor(traffic_light, "cycle")

timeout_interval=0.1

try:
    # Start the supervisor with a 0.1-second interval
    supervisor.start(interval=timeout_interval)

    # Run indefinitely, until interrupted
    print("Running indefinitely. Press Ctrl+C to stop.")
    while True:
        pass

except KeyboardInterrupt:
    print("\nStopping supervisor...")

finally:
    # Stop the supervisor when interrupted
    supervisor.stop()
    print("Supervisor stopped.")
# Out:
# Running indefinitely. Press Ctrl+C to stop.
# 2024-12-11T13:53:22.880306 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:22.980428 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:23.080355 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:23.180483 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:23.280268 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:23.380489 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:23.480459 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:23.580429 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:23.680708 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:23.780462 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:23.880423 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:23.980297 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:24.080423 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:24.180301 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:24.280307 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:24.380391 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:24.480343 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:24.580449 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:24.680416 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:24.780481 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:24.880354 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:24.980308 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:25.080329 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:25.180415 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:25.280316 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:25.380390 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:25.480363 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:25.580354 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:25.680505 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:25.780367 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:25.880485 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:25.980424 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:26.080375 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:26.180538 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:26.280374 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:26.380374 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:26.480536 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:26.580534 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:26.680781 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:26.780293 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:26.880340 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:26.980574 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:27.080312 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:27.180454 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:27.280403 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:27.380420 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:27.480414 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:27.580769 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:27.680403 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:27.780507 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:27.880472 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:27.980485 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:28.080302 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:28.180388 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:28.280565 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:28.380526 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:28.480580 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:28.580519 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:28.680516 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:28.780380 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:28.880524 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:28.980612 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:29.080502 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:29.180580 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:29.280444 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:29.380374 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:29.480279 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:29.580631 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:29.680293 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:29.780371 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:29.880607 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:29.980319 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:30.080343 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:30.180382 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:30.280332 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:30.380492 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:30.480815 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:30.580533 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:30.680418 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:30.780526 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:30.880591 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:30.980421 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:31.080501 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:31.180341 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:31.280361 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:31.380448 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:31.480435 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:31.580363 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:31.680490 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:31.780303 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:31.880278 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:31.980295 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:32.080322 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:32.180411 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:32.280320 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:32.380276 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:32.480639 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:32.580524 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:32.680372 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:32.780409 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:32.880510 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:32.980416 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:33.080379 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:33.180371 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
# 2024-12-11T13:53:33.280403 - Signal received: 14. Triggering event: cycle
# Running cycle from red to green
# 2024-12-11T13:53:33.380412 - Signal received: 14. Triggering event: cycle
# Running cycle from green to yellow
# 2024-12-11T13:53:33.480445 - Signal received: 14. Triggering event: cycle
# Running cycle from yellow to red
#
# Stopping supervisor...
# Supervisor stopped.
